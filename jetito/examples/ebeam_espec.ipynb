# %%
from jetito.ebeam import espec

# %%
parent_folder = "/raid/home/fsalgado/Projects/Jetito/jetito/examples/images/JETi-200/ebeam_espec/e-spec"
set_folder = None
data = espec.espec(parent_folder=parent_folder)

# %%
data.getEspec(shotnumber=176, save_folder="/raid/home/fsalgado/Projects/Jetito/jetito/examples/results/ebeam/espec/",
              calib_file="../ebeam/espec_calib_files/",
              verbose=True)
# Out:
# Image e-spec 1:/raid/home/fsalgado/Projects/Jetito/jetito/examples/images/JETi-200/ebeam_espec/e-spec/e-spec_1/176_Espec1_Test181605_.png
# Image e-spec 2:/raid/home/fsalgado/Projects/Jetito/jetito/examples/images/JETi-200/ebeam_espec/e-spec/e-spec_2/176_Espec2_Test181605_.png
# Image e-spec 3:/raid/home/fsalgado/Projects/Jetito/jetito/examples/images/JETi-200/ebeam_espec/e-spec/e-spec_3/176_Espec3_Test181605_.png
